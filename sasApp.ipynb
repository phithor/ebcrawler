# %%
from sasCrawler import fetch_price, parse_results
import pandas as pd

# %%
a = fetch_price("OSL", "ICN", "20180801", "20180808", "star", "1")

# %%
df1, df2 = parse_results(a)
# Out:
# Number of results Out: 10
# Number of results In: 3

# %%
df1
# Out:
#     origin destination Departure Date Departure Time Arrival Date  \
# F0     OSL         ICN     2018-08-01       12:50:00   2018-08-02
# F1     OSL         ICN     2018-08-01       16:05:00   2018-08-02
# F10    OSL         ICN     2018-08-01       12:50:00   2018-08-02
# F2     OSL         ICN     2018-08-01       16:00:00   2018-08-02
# F3     OSL         ICN     2018-08-01       15:20:00   2018-08-02
# F4     OSL         ICN     2018-08-01       15:10:00   2018-08-02
# F5     OSL         ICN     2018-08-01       09:50:00   2018-08-02
# F6     OSL         ICN     2018-08-01       09:50:00   2018-08-02
# F7     OSL         ICN     2018-08-01       14:15:00   2018-08-02
# F9     OSL         ICN     2018-08-01       09:15:00   2018-08-02
#
#     Arrival Time connectionDuration          via  Carrier(s)  \
# F0      11:20:00           15:30:00          FRA          LH
# F1      16:35:00           17:30:00      FRA,PEK  LH, CA, CA
# ...

# %%
df2
# Out:
#    origin destination Departure Date Departure Time Arrival Date Arrival Time  \
# F0    ICN         OSL     2018-08-08       14:20:00   2018-08-08     22:10:00
# F1    ICN         OSL     2018-08-08       14:20:00   2018-08-08     22:55:00
# F2    ICN         OSL     2018-08-08       17:30:00   2018-08-09     07:25:00
#
#    connectionDuration  via Carrier(s)     Cabin Classes avlSeats       Points  \
# F0           14:50:00  FRA     LH, SK           ECONOMY        1        45000
# F1           15:35:00  FRA         LH  BUSINESS,ECONOMY      6,1  70000,45000
# F2           20:55:00  BKK         TG          BUSINESS        2        70000
#
#                           Aircrafts
# F0  Airbus A340-600, Boeing 737-800
# F1    Airbus A340-600, Airbus A320
# F2   Boeing 777-300, Boeing 777-300
